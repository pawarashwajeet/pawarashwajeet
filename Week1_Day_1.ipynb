# %% [markdown]
# <a href="https://colab.research.google.com/github/pawarashwajeet/pawarashwajeet/blob/main/Week1_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Week1 Day1: Python Coding as an Essential Skil: Introduction
# 1. Python Environment: Local vs Clound
# 2. Google Colab Features
# 3. NumPy for Scientific Computing
# 4. Matplotlib: Generating Publication quality flow visualization
# ```
# # This is formatted as code
# ```
